# %% [markdown]
# ## Import

# %%
import urllib.request
from bs4 import BeautifulSoup
import requests
import re
from database import Database
import pandas as pd
import json
import time

from database import Database
import functions

# %%
#init
database = Database()

#create tables
database.create_table_championships()

database.create_table_teams()
database.create_table_players()
database.create_table_participations()
database.create_table_contracts()

database.create_table_matches()
database.create_table_matches_teams()
database.create_table_goals()

# %% [markdown]
# ## Scrapping Alexandre

# %%
def connect(url):
    url = url
    response = requests.get(url)
    if response.ok:
      soup = BeautifulSoup(response.text,'html.parser')
    else:
      print(f'L\'erreur {response.status_code} s\'est produite')
    return soup

# %%
home = connect('https://www.lequipe.fr/Football/ligue-1/page-classement-equipes/general')

# %%
ls_teams = []
for link in home.find_all('a', attrs={'class':'table__link'}):
    if link.has_attr('href'):
        ls_teams.append('https://www.lequipe.fr' + link['href'])
# Out:
# ['https://www.lequipe.fr/Football/FootballFicheClub43.html', 'https://www.lequipe.fr/Football/FootballFicheClub26.html', 'https://www.lequipe.fr/Football/FootballFicheClub25.html', 'https://www.lequipe.fr/Football/FootballFicheClub22.html', 'https://www.lequipe.fr/Football/FootballFicheClub6.html', 'https://www.lequipe.fr/Football/FootballFicheClub14.html', 'https://www.lequipe.fr/Football/FootballFicheClub9.html', 'https://www.lequipe.fr/Football/FootballFicheClub17.html', 'https://www.lequipe.fr/Football/FootballFicheClub46.html', 'https://www.lequipe.fr/Football/FootballFicheClub20.html', 'https://www.lequipe.fr/Football/FootballFicheClub38.html', 'https://www.lequipe.fr/Football/FootballFicheClub18.html', 'https://www.lequipe.fr/Football/FootballFicheClub374.html', 'https://www.lequipe.fr/Football/FootballFicheClub211.html', 'https://www.lequipe.fr/Football/FootballFicheClub13.html', 'https://www.lequipe.fr/Football/FootballFicheClub11.html', 'https://www.lequipe.fr/Football/FootballFicheClub267.html', 'https://www.lequipe.fr/Football/FootballFicheClub15.html', 'https://www.lequipe.fr/Football/FootballFicheClub47.html', 'https://www.lequipe.fr/Football/FootballFicheClub202.html']

# %%
name,country,start_year,end_year = "Ligue 1 UberEats", "France", 2020, 2021
championship_id = database.insert_table_championships(name,country,start_year,end_year)

# %%
for link in ls_teams:
    link_teams = connect(str(link))
    name = link_teams.td.strong.text
    city = link_teams.section.h1.text
    if "(" in city:
        city = city.split()
        del city[1]
        city= city[0]
    else:
        city
    date_creation = link_teams.select('td > strong')[1].text
    president = link_teams.select('td > strong')[2].text
    coach_name = link_teams.select('td > a > strong')[0].text
    
    team_id = database.insert_table_teams(name,city,coach_name,president,date_creation)
    database.insert_table_participations(team_id,championship_id)

# %%
for link in ls_teams:
    link_teams = connect(str(link))
    team_name = link_teams.select("h1.nom_sportif")
    team_name = [i.text for i in team_name]
    if "(" in team_name[0]:
        team_name = team_name[0].split()
        del team_name[1]
        team_name
    else:
        team_name[0]

    name=link_teams.select("td.nom>a")
    name = [i.text for i in name]
    del name[-1]
    name = repalce_com_ls(name, "      ", '')
    name = repalce_com_ls(name, " ", '')
    nationality = link_teams.select("td.pays")
    nationality = [i.text for i in nationality]    
    birthdate = link_teams.find_all("td", attrs={'class':'ddn'})
    birthdate = [i.text for i in birthdate]
    position =  link_teams.find_all("td", attrs={'class':'poste'})
    position =  [i.text for i in position]

    for name,birthdate,position,nationality in zip(name,birthdate,position,nationality):
        team_id = database.get_team_id(team_name[0])
        player_id = database.insert_table_players(name,position,birthdate,nationality)
        database.insert_table_contracts(player_id,team_id)

# %% [markdown]
# ## Scrapping Flo

# %%
page = requests.get('https://iphdata.lequipe.fr/iPhoneDatas/EFR/STD/ALL/V1/Football/CalendarList/CompetitionPhase/ligue-1/current/1re-journee.json')

# %%
pages = [page.json()]
for i in range(2, 39, 1):
    request = requests.get(f"https://iphdata.lequipe.fr/iPhoneDatas/EFR/STD/ALL/V1/Football/CalendarList/CompetitionPhase/ligue-1/current/{i}e-journee.json")
    pages.append(request.json())

# %%
df_scrap = pd.DataFrame(columns=['City', 'Date', 'Hour', 'Winner', 'Home','HomeGoals', 'Visitor', 'VisitorGoals', 'Week', 'Web'])

# %%
count = 0
for k in range(len(pages)):
    count+=1
    jpage = pages[k]
    for i in range(len(jpage['items']) - 1):
        for j in range (len(jpage['items'][i]['items'])):
            event = jpage['items'][i]['items'][j]['event']
            city_match = event['lieu']['ville']
            date_match = event['date']
            winner = event['specifics']['vainqueur']
            visitor_team = event['specifics']['exterieur']['equipe']['nom']
            home_team = event['specifics']['domicile']['equipe']['nom']
            visitor_goals = event['specifics']['score']['exterieur']
            home_goals = event['specifics']['score']['domicile']
            link_web = event['lien_web']
            df_scrap = df_scrap.append({'City' : city_match, 'Date' : date_match, 'Winner' : winner, 'Visitor' : visitor_team, 'Home' : home_team, 'VisitorGoals' : visitor_goals, 'HomeGoals' : home_goals, 'Week' : count, 'Web' : link_web}, ignore_index=True)

# %%
df_scrap['Date'] = df_scrap['Date'].str.split('T')
df_scrap['Hour'] = df_scrap['Date'][0][1]
df_scrap['Date'] = df_scrap['Date'][0][0]
df_scrap['Hour'] = df_scrap['Hour'].str.split('+')
df_scrap['Hour'] = df_scrap['Hour'][0][0]

# %%
df_match = df_scrap[['City', 'Date', 'Hour']]
df_home_team = df_scrap[['Home', 'HomeGoals']]
df_visitor_team = df_scrap[['Visitor', 'VisitorGoals']]

# %%
for i in range(len(df_match)):
    time.sleep(0.5)
    place = df_match.loc[i]['City']
    date = df_match.loc[i]['Date']
    hour = df_match.loc[i]['Hour']
    date = date.replace("-"," ")
    #print(date,place,hour)
    link_weather = functions.create_link_weather(place, date)
    #print(link_weather)
    tmax, rainfall = functions.scrapmeteo(link_weather)
    match_id = database.insert_table_matches(championship_id,date,place,rainfall,tmax)

    
    #for i in range(len(df_home_team)):  #matches_teams Dom
    name_city = df_home_team.loc[i]['Home']
    team_goal = df_home_team.loc[i]['HomeGoals']
    home=True

    team_id = database.get_team_id(name_city)
    #print(match_id, team_id, home, team_goal)
    database.insert_table_matches_teams(match_id, team_id, home, team_goal)
        
        
    #for i in range(len(df_visitor_team)): #matches_teams Ext
    name_city = df_visitor_team.loc[i]['Visitor']
    team_goal = df_visitor_team.loc[i]['VisitorGoals']
    home=False

    team_id = database.get_team_id(name_city)
    #print(match_id, team_id, home, team_goal)
    database.insert_table_matches_teams(match_id, team_id, home, team_goal)
        
        

    #for i in range(len(df_scrap)):
    page = requests.get(df_scrap.loc[i]['Web'])
    soup = BeautifulSoup(page.text, 'html.parser')
    goalers = soup.find_all("span", {"class": "Scoreboard__scorer"})
    for j in range(len(goalers)):
        goal_type = soup.find_all("div", {"class": "Scoreboard__goals"})
        goal_type = goal_type[j].find_all('span')
        if ((goal_type[0].text or goal_type[2].text) != '(csc)' and (goal_type[0].text or goal_type[2].text) != '(s.p.)'):
            if len(goal_type[0].text) > 1:
                #print(f'Journée : {df_scrap.loc[i].Week}, Buteur : {goalers[j].text}, type : but, equipe : {df_scrap.loc[i].Visitor} ')
                player_name = goalers[j].text.replace(" ","")
                #print(player_name)
                player_id = database.get_player_id(player_name)
                goal_type = "normal"
                database.insert_table_goals(player_id, match_id, goal_type)                
            else:
                #print(f'Journée : {df_scrap.loc[i].Week}, Buteur : {goalers[j].text}, type : but, equipe : {df_scrap.loc[i].Home} ')
                player_name = goalers[j].text.replace(" ","")
                #print(player_name)
                player_id = database.get_player_id(player_name)
                goal_type = "normal"
                database.insert_table_goals(player_id, match_id, goal_type)
                #print(f'Journée : {df_scrap.loc[i].Week}, Buteur : {goalers[j].text}, type : but')
        elif ((goal_type[0].text or goal_type[2].text) == '(s.p.)'):
            if (goal_type[0].text == '(s.p.)'):
                #print(f'Journée : {df_scrap.loc[i].Week}, Buteur : {goalers[j].text}, type : penalty, equipe : {df_scrap.loc[i].Home} ')
                player_name = goalers[j].text.replace(" ","")
                #print(player_name)
                player_id = database.get_player_id(player_name)
                goal_type = "penalty"
                database.insert_table_goals(player_id, match_id, goal_type)
            else:
                #print(f'Journée : {df_scrap.loc[i].Week}, Buteur : {goalers[j].text}, type : penalty, equipe : {df_scrap.loc[i].Visitor} ')
                player_name = goalers[j].text.replace(" ","")
                #print(player_name)
                player_id = database.get_player_id(player_name)
                goal_type = "penalty"
                database.insert_table_goals(player_id, match_id, goal_type)
        elif ((goal_type[0].text or goal_type[2].text) == '(csc)'):
            if (goal_type[0].text == '(csc)'):
                #print(f'Journée : {df_scrap.loc[i].Week}, Buteur : {goalers[j].text}, type : contre son camp, equipe : {df_scrap.loc[i].Home} ')
                player_name = goalers[j].text.replace(" ","")
                #print(player_name)
                player_id = database.get_player_id(player_name)
                goal_type = "contre son camp"
                database.insert_table_goals(player_id, match_id, goal_type)
            else:
                #print(f'Journée : {df_scrap.loc[i].Week}, Buteur : {goalers[j].text}, type : contre son camp, equipe : {df_scrap.loc[i].Visitor} ')
                player_name = goalers[j].text.replace(" ","")
                #print(player_name)
                player_id = database.get_player_id(player_name)
                goal_type = "contre son camp"
                database.insert_table_goals(player_id, match_id, goal_type)
# Out:
# 2020 08 21 Bordeaux 19:00:00
# https://www.historique-meteo.net/france/aquitaine/bordeaux/2020/08/21/
# 1 12 True 0
# 1 18 False 0
# 2020 08 21 Dijon 19:00:00
# https://www.historique-meteo.net/france/bourgogne/dijon/2020/08/21/
# 2 20 True 0
# 2 13 False 1
# Journée : 1, Buteur : I. Traoré, type : but, equipe : Angers
# I.Traoré
# 2020 08 21 Lille 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lille/2020/08/21/
# 3 1 True 1
# 3 6 False 1
# Journée : 1, Buteur : J. Bamba, type : but, equipe : Lille
# J.Bamba
# Journée : 1, Buteur : D. Da Silva, type : but, equipe : Rennes
# D.DaSilva
# 2020 08 21 Monaco 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/monaco/2020/08/21/
# 4 3 True 2
# 4 14 False 2
# Journée : 1, Buteur : A. Disasi, type : but, equipe : Monaco
# A.Disasi
# Journée : 1, Buteur : B. Badiashile, type : but, equipe : Monaco
# B.Badiashile
# Journée : 1, Buteur : B. Dia, type : but, equipe : Reims
# B.Dia
# Journée : 1, Buteur : E. Touré, type : but, equipe : Reims
# E.Touré
# 2020 08 21 Lorient 19:00:00
# https://www.historique-meteo.net/france/bretagne/lorient/2020/08/21/
# 5 16 True 3
# 5 15 False 1
# Journée : 1, Buteur : Y. Wissa, type : but, equipe : Lorient
# Y.Wissa
# Journée : 1, Buteur : A. Grbic, type : penalty, equipe : Lorient
# A.Grbic
# Journée : 1, Buteur : P. Hamel, type : but, equipe : Lorient
# P.Hamel
# Journée : 1, Buteur : M. Chahiri, type : but, equipe : Strasbourg
# M.Chahiri
# 2020 08 21 Nîmes 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/nimes/2020/08/21/
# 6 19 True 4
# 6 17 False 0
# Journée : 1, Buteur : K. Denkey, type : but, equipe : Nîmes
# K.Denkey
# Journée : 1, Buteur : B. Meling, type : but, equipe : Nîmes
# B.Meling
# Journée : 1, Buteur : R. Philippoteaux, type : but, equipe : Nîmes
# R.Philippoteaux
# Journée : 1, Buteur : M. Koné, type : but, equipe : Nîmes
# M.Koné
# 2020 08 21 Nice 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/nice/2020/08/21/
# 7 9 True 2
# 7 7 False 1
# Journée : 1, Buteur : A. Gouiri, type : but, equipe : Nice
# A.Gouiri
# Journée : 1, Buteur : A. Gouiri, type : but, equipe : Nice
# A.Gouiri
# Journée : 1, Buteur : G. Kakuta, type : but, equipe : Lens
# G.Kakuta
# 2020 08 21 Montpellier 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/montpellier/2020/08/21/
# 8 8 True 2
# 8 4 False 1
# Journée : 1, Buteur : T. Savanier, type : penalty, equipe : Montpellier
# T.Savanier
# Journée : 1, Buteur : T. Savanier, type : but, equipe : Montpellier
# T.Savanier
# Journée : 1, Buteur : M. Depay, type : but, equipe : Lyon
# M.Depay
# 2020 08 21 Paris 19:00:00
# https://www.historique-meteo.net/france/ile-de-france/paris/2020/08/21/
# 9 2 True 1
# 9 10 False 0
# Journée : 1, Buteur : J. Draxler, type : but, equipe : Paris-SG
# J.Draxler
# 2020 08 21 Marseille 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/marseille/2020/08/21/
# 10 5 True 0
# 10 11 False 2
# Journée : 1, Buteur : R. Hamouma, type : but, equipe : Saint-Étienne
# R.Hamouma
# Journée : 1, Buteur : D. Bouanga, type : but, equipe : Saint-Étienne
# D.Bouanga
# 2020 08 21 Lyon 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/lyon/2020/08/21/
# 11 4 True 4
# 11 20 False 1
# Journée : 2, Buteur : M. Depay, type : penalty, equipe : Lyon
# M.Depay
# Journée : 2, Buteur : W. Lautoa, type : contre son camp, equipe : Lyon
# W.Lautoa
# Journée : 2, Buteur : M. Depay, type : but, equipe : Lyon
# M.Depay
# Journée : 2, Buteur : M. Depay, type : penalty, equipe : Lyon
# M.Depay
# Journée : 2, Buteur : A. Scheidler, type : but, equipe : Dijon
# A.Scheidler
# 2020 08 21 Rennes 19:00:00
# https://www.historique-meteo.net/france/bretagne/rennes/2020/08/21/
# 12 6 True 2
# 12 8 False 1
# Journée : 2, Buteur : D. Le Tallec, type : contre son camp, equipe : Rennes
# D.LeTallec
# Journée : 2, Buteur : E. Camavinga, type : but, equipe : Rennes
# E.Camavinga
# Journée : 2, Buteur : G. Laborde, type : but, equipe : Montpellier
# G.Laborde
# 2020 08 21 Strasbourg 19:00:00
# https://www.historique-meteo.net/france/alsace/strasbourg/2020/08/21/
# 13 15 True 0
# 13 9 False 2
# Journée : 2, Buteur : K. Dolberg, type : but, equipe : Nice
# K.Dolberg
# Journée : 2, Buteur : K. Dolberg, type : but, equipe : Nice
# K.Dolberg
# 2020 08 21 Reims 19:00:00
# https://www.historique-meteo.net/france/champagne-ardenne/reims/2020/08/21/
# 14 14 True 0
# 14 1 False 1
# Journée : 2, Buteur : J. Bamba, type : but, equipe : Lille
# J.Bamba
# 2020 08 21 Nantes 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/nantes/2020/08/21/
# 15 18 True 2
# 15 19 False 1
# Journée : 2, Buteur : A. Girotto, type : but, equipe : Nantes
# A.Girotto
# Journée : 2, Buteur : I. Louza, type : penalty, equipe : Nantes
# I.Louza
# Journée : 2, Buteur : Z. Ferhat, type : but, equipe : Nîmes
# Z.Ferhat
# 2020 08 21 Saint-Étienne 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/saint-etienne/2020/08/21/
# 16 11 True 2
# 16 16 False 0
# Journée : 2, Buteur : R. Hamouma, type : but, equipe : Saint-Étienne
# R.Hamouma
# Journée : 2, Buteur : R. Hamouma, type : but, equipe : Saint-Étienne
# R.Hamouma
# 2020 08 21 Angers 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/angers/2020/08/21/
# 17 13 True 0
# 17 12 False 2
# Journée : 2, Buteur : J. Maja, type : but, equipe : Bordeaux
# J.Maja
# Journée : 2, Buteur : T. Basic, type : but, equipe : Bordeaux
# T.Basic
# 2020 08 21 Metz 19:00:00
# https://www.historique-meteo.net/france/lorraine/metz/2020/08/21/
# 18 10 True 0
# 18 3 False 1
# Journée : 2, Buteur : B. Badiashile, type : but, equipe : Monaco
# B.Badiashile
# 2020 08 21 Brest 19:00:00
# https://www.historique-meteo.net/france/bretagne/brest/2020/08/21/
# 19 17 True 2
# 19 5 False 3
# Journée : 2, Buteur : R. Faivre, type : but, equipe : Brest
# R.Faivre
# Journée : 2, Buteur : G. Charbonnier, type : but, equipe : Brest
# G.Charbonnier
# Journée : 2, Buteur : F. Thauvin, type : but, equipe : Marseille
# F.Thauvin
# Journée : 2, Buteur : D. Caleta-Car, type : but, equipe : Marseille
# D.Caleta-Car
# Journée : 2, Buteur : D. Caleta-Car, type : but, equipe : Marseille
# D.Caleta-Car
# 2020 08 21 Lens 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lens/2020/08/21/
# 20 7 True 1
# 20 2 False 0
# Journée : 2, Buteur : I. Ganago, type : but, equipe : Lens
# I.Ganago
# 2020 08 21 Bordeaux 19:00:00
# https://www.historique-meteo.net/france/aquitaine/bordeaux/2020/08/21/
# 21 12 True 0
# 21 4 False 0
# 2020 08 21 Montpellier 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/montpellier/2020/08/21/
# 22 8 True 3
# 22 9 False 1
# Journée : 3, Buteur : G. Laborde, type : but, equipe : Montpellier
# G.Laborde
# Journée : 3, Buteur : D. Congré, type : but, equipe : Montpellier
# D.Congré
# Journée : 3, Buteur : D. Congré, type : but, equipe : Montpellier
# D.Congré
# Journée : 3, Buteur : Dante, type : but, equipe : Nice
# Dante
# 2020 08 21 Saint-Étienne 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/saint-etienne/2020/08/21/
# 23 11 True 2
# 23 15 False 0
# Journée : 3, Buteur : D. Bouanga, type : penalty, equipe : Saint-Étienne
# D.Bouanga
# Journée : 3, Buteur : M. Camara, type : but, equipe : Saint-Étienne
# M.Camara
# 2020 08 21 Lille 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lille/2020/08/21/
# 24 1 True 1
# 24 10 False 0
# Journée : 3, Buteur : L. Araujo, type : but, equipe : Lille
# L.Araujo
# 2020 08 21 Nîmes 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/nimes/2020/08/21/
# 25 19 True 2
# 25 6 False 4
# Journée : 3, Buteur : A. Cubas, type : but, equipe : Nîmes
# A.Cubas
# Journée : 3, Buteur : Z. Ferhat, type : but, equipe : Nîmes
# Z.Ferhat
# Journée : 3, Buteur : S. Guirassy, type : but, equipe : Rennes
# S.Guirassy
# Journée : 3, Buteur : S. Guirassy, type : but, equipe : Rennes
# S.Guirassy
# Journée : 3, Buteur : N. Aguerd, type : but, equipe : Rennes
# N.Aguerd
# Journée : 3, Buteur : B. Bourigeaud, type : but, equipe : Rennes
# B.Bourigeaud
# 2020 08 21 Lorient 19:00:00
# https://www.historique-meteo.net/france/bretagne/lorient/2020/08/21/
# 26 16 True 2
# 26 7 False 3
# Journée : 3, Buteur : A. Grbic, type : but, equipe : Lorient
# A.Grbic
# Journée : 3, Buteur : Y. Wissa, type : penalty, equipe : Lorient
# Y.Wissa
# Journée : 3, Buteur : G. Kakuta, type : but, equipe : Lens
# G.Kakuta
# Journée : 3, Buteur : F. Medina, type : but, equipe : Lens
# F.Medina
# Journée : 3, Buteur : I. Ganago, type : but, equipe : Lens
# I.Ganago
# 2020 08 21 Angers 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/angers/2020/08/21/
# 27 13 True 1
# 27 14 False 0
# Journée : 3, Buteur : S. Bahoken, type : but, equipe : Angers
# S.Bahoken
# 2020 08 21 Dijon 19:00:00
# https://www.historique-meteo.net/france/bourgogne/dijon/2020/08/21/
# 28 20 True 0
# 28 17 False 2
# Journée : 3, Buteur : R. Perraud, type : but, equipe : Brest
# R.Perraud
# Journée : 3, Buteur : I. Cardona, type : but, equipe : Brest
# I.Cardona
# 2020 08 21 Monaco 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/monaco/2020/08/21/
# 29 3 True 2
# 29 18 False 1
# Journée : 3, Buteur : S. Diop, type : but, equipe : Monaco
# S.Diop
# Journée : 3, Buteur : W. Geubbels, type : but, equipe : Monaco
# W.Geubbels
# Journée : 3, Buteur : L. Blas, type : but, equipe : Nantes
# L.Blas
# 2020 08 21 Paris 19:00:00
# https://www.historique-meteo.net/france/ile-de-france/paris/2020/08/21/
# 30 2 True 0
# 30 5 False 1
# Journée : 3, Buteur : F. Thauvin, type : but, equipe : Marseille
# F.Thauvin
# 2020 08 21 Lyon 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/lyon/2020/08/21/
# 31 4 True 0
# 31 19 False 0
# 2020 08 21 Lens 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lens/2020/08/21/
# 32 7 True 2
# 32 12 False 1
# Journée : 4, Buteur : I. Ganago, type : but, equipe : Lens
# I.Ganago
# Journée : 4, Buteur : G. Kakuta, type : penalty, equipe : Lens
# G.Kakuta
# Journée : 4, Buteur : S. Kalu, type : but, equipe : Bordeaux
# S.Kalu
# 2020 08 21 Rennes 19:00:00
# https://www.historique-meteo.net/france/bretagne/rennes/2020/08/21/
# 33 6 True 2
# 33 3 False 1
# Journée : 4, Buteur : S. Nzonzi, type : but, equipe : Rennes
# S.Nzonzi
# Journée : 4, Buteur : A. Truffert, type : but, equipe : Rennes
# A.Truffert
# Journée : 4, Buteur : W. Ben Yedder, type : but, equipe : Monaco
# W.BenYedder
# 2020 08 21 Nice 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/nice/2020/08/21/
# 34 9 True 0
# 34 2 False 3
# Journée : 4, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# Journée : 4, Buteur : A. Di Maria, type : but, equipe : Paris-SG
# A.DiMaria
# Journée : 4, Buteur : Marquinhos, type : but, equipe : Paris-SG
# Marquinhos
# 2020 08 21 Montpellier 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/montpellier/2020/08/21/
# 35 8 True 4
# 35 13 False 1
# Journée : 4, Buteur : A. Souquet, type : but, equipe : Montpellier
# A.Souquet
# Journée : 4, Buteur : A. Delort, type : but, equipe : Montpellier
# A.Delort
# Journée : 4, Buteur : A. Delort, type : but, equipe : Montpellier
# A.Delort
# Journée : 4, Buteur : F. Mollet, type : but, equipe : Montpellier
# F.Mollet
# Journée : 4, Buteur : S. Bahoken, type : but, equipe : Angers
# S.Bahoken
# 2020 08 21 Brest 19:00:00
# https://www.historique-meteo.net/france/bretagne/brest/2020/08/21/
# 36 17 True 3
# 36 16 False 2
# Journée : 4, Buteur : R. Perraud, type : but, equipe : Brest
# R.Perraud
# Journée : 4, Buteur : S. Mounié, type : but, equipe : Brest
# S.Mounié
# Journée : 4, Buteur : F. Honorat, type : but, equipe : Brest
# F.Honorat
# Journée : 4, Buteur : C. Hérelle, type : but, equipe : Lorient
# C.Hérelle
# Journée : 4, Buteur : T. Monconduit, type : but, equipe : Lorient
# T.Monconduit
# 2020 08 21 Metz 19:00:00
# https://www.historique-meteo.net/france/lorraine/metz/2020/08/21/
# 37 10 True 2
# 37 14 False 1
# Journée : 4, Buteur : I. Niane, type : but, equipe : Metz
# I.Niane
# Journée : 4, Buteur : I. Niane, type : but, equipe : Metz
# I.Niane
# Journée : 4, Buteur : B. Dia, type : but, equipe : Reims
# B.Dia
# 2020 08 21 Strasbourg 19:00:00
# https://www.historique-meteo.net/france/alsace/strasbourg/2020/08/21/
# 38 15 True 1
# 38 20 False 0
# Journée : 4, Buteur : S. Mitrovic, type : but, equipe : Strasbourg
# S.Mitrovic
# 2020 08 21 Nantes 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/nantes/2020/08/21/
# 39 18 True 2
# 39 11 False 2
# Journée : 4, Buteur : M. Simon, type : but, equipe : Nantes
# M.Simon
# Journée : 4, Buteur : R. Emond, type : but, equipe : Nantes
# R.Emond
# Journée : 4, Buteur : A. Aouchiche, type : but, equipe : Saint-Étienne
# A.Aouchiche
# Journée : 4, Buteur : Y. Maçon, type : but, equipe : Saint-Étienne
# Y.Maçon
# 2020 08 21 Marseille 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/marseille/2020/08/21/
# 40 5 True 1
# 40 1 False 1
# Journée : 4, Buteur : V. Germain, type : but, equipe : Marseille
# V.Germain
# Journée : 4, Buteur : L. Araujo, type : but, equipe : Lille
# L.Araujo
# 2020 08 21 Lille 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lille/2020/08/21/
# 41 1 True 2
# 41 18 False 0
# Journée : 5, Buteur : N. Pallois, type : contre son camp, equipe : Lille
# N.Pallois
# Journée : 5, Buteur : B. Yilmaz, type : penalty, equipe : Lille
# B.Yilmaz
# 2020 08 21 Saint-Étienne 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/saint-etienne/2020/08/21/
# 42 11 True 0
# 42 6 False 3
# Journée : 5, Buteur : N. Aguerd, type : but, equipe : Rennes
# N.Aguerd
# Journée : 5, Buteur : S. Guirassy, type : but, equipe : Rennes
# S.Guirassy
# Journée : 5, Buteur : A. Hunou, type : but, equipe : Rennes
# A.Hunou
# 2020 08 21 Marseille 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/marseille/2020/08/21/
# 43 5 True 1
# 43 10 False 1
# Journée : 5, Buteur : M. Sanson, type : but, equipe : Marseille
# M.Sanson
# Journée : 5, Buteur : I. Niane, type : but, equipe : Metz
# I.Niane
# 2020 08 21 Bordeaux 19:00:00
# https://www.historique-meteo.net/france/aquitaine/bordeaux/2020/08/21/
# 44 12 True 0
# 44 9 False 0
# 2020 08 21 Dijon 19:00:00
# https://www.historique-meteo.net/france/bourgogne/dijon/2020/08/21/
# 45 20 True 2
# 45 8 False 2
# Journée : 5, Buteur : E. Dina Ebimbe, type : but, equipe : Dijon
# E.DinaEbimbe
# Journée : 5, Buteur : B. Ecuele Manga, type : but, equipe : Dijon
# B.EcueleManga
# Journée : 5, Buteur : A. Delort, type : but, equipe : Montpellier
# A.Delort
# Journée : 5, Buteur : T. Savanier, type : but, equipe : Montpellier
# T.Savanier
# 2020 08 21 Nîmes 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/nimes/2020/08/21/
# 46 19 True 1
# 46 7 False 1
# Journée : 5, Buteur : Z. Ferhat, type : but, equipe : Nîmes
# Z.Ferhat
# Journée : 5, Buteur : I. Ganago, type : but, equipe : Lens
# I.Ganago
# 2020 08 21 Monaco 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/monaco/2020/08/21/
# 47 3 True 3
# 47 15 False 2
# Journée : 5, Buteur : W. Ben Yedder, type : but, equipe : Monaco
# W.BenYedder
# Journée : 5, Buteur : R. Aguilar, type : but, equipe : Monaco
# R.Aguilar
# Journée : 5, Buteur : W. Ben Yedder, type : but, equipe : Monaco
# W.BenYedder
# Journée : 5, Buteur : M. Chahiri, type : but, equipe : Strasbourg
# M.Chahiri
# Journée : 5, Buteur : L. Ajorque, type : but, equipe : Strasbourg
# L.Ajorque
# 2020 08 21 Angers 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/angers/2020/08/21/
# 48 13 True 3
# 48 17 False 2
# Journée : 5, Buteur : S. Thioub, type : but, equipe : Angers
# S.Thioub
# Journée : 5, Buteur : I. Traoré, type : but, equipe : Angers
# I.Traoré
# Journée : 5, Buteur : A. Fulgini, type : but, equipe : Angers
# A.Fulgini
# Journée : 5, Buteur : S. Mounié, type : but, equipe : Brest
# S.Mounié
# Journée : 5, Buteur : G. Charbonnier, type : but, equipe : Brest
# G.Charbonnier
# 2020 08 21 Lorient 19:00:00
# https://www.historique-meteo.net/france/bretagne/lorient/2020/08/21/
# 49 16 True 1
# 49 4 False 1
# Journée : 5, Buteur : Y. Wissa, type : but, equipe : Lorient
# Y.Wissa
# Journée : 5, Buteur : L. Dubois, type : but, equipe : Lyon
# L.Dubois
# 2020 08 21 Reims 19:00:00
# https://www.historique-meteo.net/france/champagne-ardenne/reims/2020/08/21/
# 50 14 True 0
# 50 2 False 2
# Journée : 5, Buteur : M. Icardi, type : but, equipe : Paris-SG
# M.Icardi
# Journée : 5, Buteur : M. Icardi, type : but, equipe : Paris-SG
# M.Icardi
# 2020 08 21 Paris 19:00:00
# https://www.historique-meteo.net/france/ile-de-france/paris/2020/08/21/
# 51 2 True 6
# 51 13 False 1
# Journée : 6, Buteur : A. Florenzi, type : but, equipe : Paris-SG
# A.Florenzi
# Journée : 6, Buteur : Neymar, type : but, equipe : Paris-SG
# Neymar
# Journée : 6, Buteur : Neymar, type : but, equipe : Paris-SG
# Neymar
# Journée : 6, Buteur : J. Draxler, type : but, equipe : Paris-SG
# J.Draxler
# Journée : 6, Buteur : I. Gueye, type : but, equipe : Paris-SG
# I.Gueye
# Journée : 6, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# Journée : 6, Buteur : I. Traoré, type : but, equipe : Angers
# I.Traoré
# 2020 08 21 Lens 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lens/2020/08/21/
# 52 7 True 2
# 52 11 False 0
# Journée : 6, Buteur : G. Kakuta, type : penalty, equipe : Lens
# G.Kakuta
# Journée : 6, Buteur : F. Sotoca, type : but, equipe : Lens
# F.Sotoca
# 2020 08 21 Nice 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/nice/2020/08/21/
# 53 9 True 2
# 53 18 False 1
# Journée : 6, Buteur : Dante, type : but, equipe : Nice
# Dante
# Journée : 6, Buteur : K. Thuram, type : but, equipe : Nice
# K.Thuram
# Journée : 6, Buteur : I. Louza, type : but, equipe : Nantes
# I.Louza
# 2020 08 21 Montpellier 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/montpellier/2020/08/21/
# 54 8 True 0
# 54 19 False 1
# Journée : 6, Buteur : R. Ripart, type : but, equipe : Nîmes
# R.Ripart
# 2020 08 21 Strasbourg 19:00:00
# https://www.historique-meteo.net/france/alsace/strasbourg/2020/08/21/
# 55 15 True 0
# 55 1 False 3
# Journée : 6, Buteur : M. Çelik, type : but, equipe : Lille
# M.Çelik
# Journée : 6, Buteur : R. Sanches, type : but, equipe : Lille
# R.Sanches
# Journée : 6, Buteur : B. Yilmaz, type : but, equipe : Lille
# B.Yilmaz
# 2020 08 21 Brest 19:00:00
# https://www.historique-meteo.net/france/bretagne/brest/2020/08/21/
# 56 17 True 1
# 56 3 False 0
# Journée : 6, Buteur : R. Faivre, type : but, equipe : Brest
# R.Faivre
# 2020 08 21 Bordeaux 19:00:00
# https://www.historique-meteo.net/france/aquitaine/bordeaux/2020/08/21/
# 57 12 True 3
# 57 20 False 0
# Journée : 6, Buteur : R. Oudin, type : but, equipe : Bordeaux
# R.Oudin
# Journée : 6, Buteur : S. Kalu, type : but, equipe : Bordeaux
# S.Kalu
# Journée : 6, Buteur : T. Basic, type : but, equipe : Bordeaux
# T.Basic
# 2020 08 21 Metz 19:00:00
# https://www.historique-meteo.net/france/lorraine/metz/2020/08/21/
# 58 10 True 3
# 58 16 False 1
# Journée : 6, Buteur : I. Niane, type : penalty, equipe : Metz
# I.Niane
# Journée : 6, Buteur : I. Niane, type : but, equipe : Metz
# I.Niane
# Journée : 6, Buteur : I. Niane, type : but, equipe : Metz
# I.Niane
# Journée : 6, Buteur : P. Hamel, type : but, equipe : Lorient
# P.Hamel
# 2020 08 21 Rennes 19:00:00
# https://www.historique-meteo.net/france/bretagne/rennes/2020/08/21/
# 59 6 True 2
# 59 14 False 2
# Journée : 6, Buteur : Raphinha, type : but, equipe : Rennes
# Raphinha
# Journée : 6, Buteur : D. Da Silva, type : but, equipe : Rennes
# D.DaSilva
# Journée : 6, Buteur : Y. Abdelhamid, type : but, equipe : Reims
# Y.Abdelhamid
# Journée : 6, Buteur : B. Dia, type : but, equipe : Reims
# B.Dia
# 2020 08 21 Lyon 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/lyon/2020/08/21/
# 60 4 True 1
# 60 5 False 1
# Journée : 6, Buteur : H. Aouar, type : penalty, equipe : Lyon
# H.Aouar
# Journée : 6, Buteur : D. Payet, type : but, equipe : Marseille
# D.Payet
# 2020 08 21 Dijon 19:00:00
# https://www.historique-meteo.net/france/bourgogne/dijon/2020/08/21/
# 61 20 True 1
# 61 6 False 1
# Journée : 7, Buteur : M. Baldé, type : but, equipe : Dijon
# M.Baldé
# Journée : 7, Buteur : M. Terrier, type : but, equipe : Rennes
# M.Terrier
# 2020 08 21 Nîmes 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/nimes/2020/08/21/
# 62 19 True 0
# 62 2 False 4
# Journée : 7, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# Journée : 7, Buteur : A. Florenzi, type : but, equipe : Paris-SG
# A.Florenzi
# Journée : 7, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# Journée : 7, Buteur : P. Sarabia, type : but, equipe : Paris-SG
# P.Sarabia
# 2020 08 21 Reims 19:00:00
# https://www.historique-meteo.net/france/champagne-ardenne/reims/2020/08/21/
# 63 14 True 1
# 63 16 False 3
# Journée : 7, Buteur : M. Cassama, type : but, equipe : Reims
# M.Cassama
# Journée : 7, Buteur : P. Hamel, type : but, equipe : Lorient
# P.Hamel
# Journée : 7, Buteur : Y. Wissa, type : but, equipe : Lorient
# Y.Wissa
# Journée : 7, Buteur : T. Moffi, type : but, equipe : Lorient
# T.Moffi
# 2020 08 21 Marseille 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/marseille/2020/08/21/
# 64 5 True 3
# 64 12 False 1
# Journée : 7, Buteur : F. Thauvin, type : but, equipe : Marseille
# F.Thauvin
# Journée : 7, Buteur : J. Amavi, type : but, equipe : Marseille
# J.Amavi
# Journée : 7, Buteur : Pablo, type : contre son camp, equipe : Marseille
# Pablo
# Journée : 7, Buteur : J. Maja, type : but, equipe : Bordeaux
# J.Maja
# 2020 08 21 Strasbourg 19:00:00
# https://www.historique-meteo.net/france/alsace/strasbourg/2020/08/21/
# 65 15 True 2
# 65 4 False 3
# Journée : 7, Buteur : H. Diallo, type : but, equipe : Strasbourg
# H.Diallo
# Journée : 7, Buteur : J. Aholou, type : but, equipe : Strasbourg
# J.Aholou
# Journée : 7, Buteur : T. Kadewere, type : but, equipe : Lyon
# T.Kadewere
# Journée : 7, Buteur : K. Toko Ekambi, type : but, equipe : Lyon
# K.TokoEkambi
# Journée : 7, Buteur : K. Toko Ekambi, type : but, equipe : Lyon
# K.TokoEkambi
# 2020 08 21 Monaco 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/monaco/2020/08/21/
# 66 3 True 1
# 66 8 False 1
# Journée : 7, Buteur : W. Ben Yedder, type : penalty, equipe : Monaco
# W.BenYedder
# Journée : 7, Buteur : S. Mavididi, type : but, equipe : Montpellier
# S.Mavididi
# 2020 08 21 Nantes 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/nantes/2020/08/21/
# 67 18 True 3
# 67 17 False 1
# Journée : 7, Buteur : R. Kolo Muani, type : but, equipe : Nantes
# R.KoloMuani
# Journée : 7, Buteur : L. Blas, type : but, equipe : Nantes
# L.Blas
# Journée : 7, Buteur : A. Bamba, type : but, equipe : Nantes
# A.Bamba
# Journée : 7, Buteur : R. Faivre, type : but, equipe : Brest
# R.Faivre
# 2020 08 21 Angers 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/angers/2020/08/21/
# 68 13 True 1
# 68 10 False 1
# Journée : 7, Buteur : T. Mangani, type : penalty, equipe : Angers
# T.Mangani
# Journée : 7, Buteur : O. Nguette, type : but, equipe : Metz
# O.Nguette
# 2020 08 21 Saint-Étienne 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/saint-etienne/2020/08/21/
# 69 11 True 1
# 69 9 False 3
# Journée : 7, Buteur : A. Aouchiche, type : but, equipe : Saint-Étienne
# A.Aouchiche
# Journée : 7, Buteur : P. Lees-Melou, type : but, equipe : Nice
# P.Lees-Melou
# Journée : 7, Buteur : A. Gouiri, type : but, equipe : Nice
# A.Gouiri
# Journée : 7, Buteur : M. Maolida, type : but, equipe : Nice
# M.Maolida
# 2020 08 21 Lille 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lille/2020/08/21/
# 70 1 True 4
# 70 7 False 0
# Journée : 7, Buteur : B. Yilmaz, type : but, equipe : Lille
# B.Yilmaz
# Journée : 7, Buteur : J. Bamba, type : but, equipe : Lille
# J.Bamba
# Journée : 7, Buteur : J. Ikoné, type : but, equipe : Lille
# J.Ikoné
# Journée : 7, Buteur : Y. Yazici, type : but, equipe : Lille
# Y.Yazici
# 2020 08 21 Rennes 19:00:00
# https://www.historique-meteo.net/france/bretagne/rennes/2020/08/21/
# 71 6 True 1
# 71 13 False 2
# Journée : 8, Buteur : A. Hunou, type : but, equipe : Rennes
# A.Hunou
# Journée : 8, Buteur : S. Boufal, type : but, equipe : Angers
# S.Boufal
# Journée : 8, Buteur : A. Fulgini, type : but, equipe : Angers
# A.Fulgini
# 2020 08 21 Lorient 19:00:00
# https://www.historique-meteo.net/france/bretagne/lorient/2020/08/21/
# 72 16 True 0
# 72 5 False 1
# Journée : 8, Buteur : L. Balerdi, type : but, equipe : Marseille
# L.Balerdi
# 2020 08 21 Paris 19:00:00
# https://www.historique-meteo.net/france/ile-de-france/paris/2020/08/21/
# 73 2 True 4
# 73 20 False 0
# Journée : 8, Buteur : M. Kean, type : but, equipe : Paris-SG
# M.Kean
# Journée : 8, Buteur : M. Kean, type : but, equipe : Paris-SG
# M.Kean
# Journée : 8, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# Journée : 8, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# 2020 08 21 Montpellier 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/montpellier/2020/08/21/
# 74 8 True 0
# 74 14 False 4
# Journée : 8, Buteur : B. Dia, type : but, equipe : Reims
# B.Dia
# Journée : 8, Buteur : B. Dia, type : but, equipe : Reims
# B.Dia
# Journée : 8, Buteur : N. Mbuku, type : but, equipe : Reims
# N.Mbuku
# Journée : 8, Buteur : B. Dia, type : but, equipe : Reims
# B.Dia
# 2020 08 21 Metz 19:00:00
# https://www.historique-meteo.net/france/lorraine/metz/2020/08/21/
# 75 10 True 2
# 75 11 False 0
# Journée : 8, Buteur : F. Boulaya, type : but, equipe : Metz
# F.Boulaya
# Journée : 8, Buteur : N. Sissoko, type : contre son camp, equipe : Metz
# N.Sissoko
# 2020 08 21 Bordeaux 19:00:00
# https://www.historique-meteo.net/france/aquitaine/bordeaux/2020/08/21/
# 76 12 True 2
# 76 19 False 0
# Journée : 8, Buteur : J. Briand, type : penalty, equipe : Bordeaux
# J.Briand
# Journée : 8, Buteur : R. Oudin, type : but, equipe : Bordeaux
# R.Oudin
# 2020 08 21 Brest 19:00:00
# https://www.historique-meteo.net/france/bretagne/brest/2020/08/21/
# 77 17 True 0
# 77 15 False 3
# Journée : 8, Buteur : H. Diallo, type : but, equipe : Strasbourg
# H.Diallo
# Journée : 8, Buteur : K. Lala, type : but, equipe : Strasbourg
# K.Lala
# Journée : 8, Buteur : L. Ajorque, type : but, equipe : Strasbourg
# L.Ajorque
# 2020 08 21 Nice 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/nice/2020/08/21/
# 78 9 True 1
# 78 1 False 1
# Journée : 8, Buteur : K. Dolberg, type : but, equipe : Nice
# K.Dolberg
# Journée : 8, Buteur : B. Yilmaz, type : but, equipe : Lille
# B.Yilmaz
# 2020 08 21 Lyon 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/lyon/2020/08/21/
# 79 4 True 4
# 79 3 False 1
# Journée : 8, Buteur : M. Depay, type : but, equipe : Lyon
# M.Depay
# Journée : 8, Buteur : K. Toko Ekambi, type : but, equipe : Lyon
# K.TokoEkambi
# Journée : 8, Buteur : H. Aouar, type : penalty, equipe : Lyon
# H.Aouar
# Journée : 8, Buteur : K. Toko Ekambi, type : but, equipe : Lyon
# K.TokoEkambi
# Journée : 8, Buteur : W. Ben Yedder, type : but, equipe : Monaco
# W.BenYedder
# 2020 08 21 Lens 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lens/2020/08/21/
# 80 7 True 1
# 80 18 False 1
# Journée : 8, Buteur : G. Kakuta, type : but, equipe : Lens
# G.Kakuta
# Journée : 8, Buteur : A. Touré, type : but, equipe : Nantes
# A.Touré
# 2020 08 21 Rennes 19:00:00
# https://www.historique-meteo.net/france/bretagne/rennes/2020/08/21/
# 81 6 True 2
# 81 17 False 1
# Journée : 9, Buteur : D. Da Silva, type : but, equipe : Rennes
# D.DaSilva
# Journée : 9, Buteur : N. Aguerd, type : but, equipe : Rennes
# N.Aguerd
# Journée : 9, Buteur : F. Honorat, type : but, equipe : Brest
# F.Honorat
# 2020 08 21 Nantes 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/nantes/2020/08/21/
# 82 18 True 0
# 82 2 False 3
# Journée : 9, Buteur : A. Herrera, type : but, equipe : Paris-SG
# A.Herrera
# Journée : 9, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# Journée : 9, Buteur : P. Sarabia, type : but, equipe : Paris-SG
# P.Sarabia
# 2020 08 21 Saint-Étienne 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/saint-etienne/2020/08/21/
# 83 11 True 0
# 83 8 False 1
# Journée : 9, Buteur : S. Mavididi, type : but, equipe : Montpellier
# S.Mavididi
# 2020 08 21 Angers 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/angers/2020/08/21/
# 84 13 True 0
# 84 9 False 3
# Journée : 9, Buteur : R. Lopes, type : but, equipe : Nice
# R.Lopes
# Journée : 9, Buteur : P. Lees-Melou, type : but, equipe : Nice
# P.Lees-Melou
# Journée : 9, Buteur : H. Boudaoui, type : but, equipe : Nice
# H.Boudaoui
# 2020 08 21 Nîmes 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/nimes/2020/08/21/
# 85 19 True 0
# 85 10 False 1
# Journée : 9, Buteur : M. Gueye, type : but, equipe : Metz
# M.Gueye
# 2020 08 21 Dijon 19:00:00
# https://www.historique-meteo.net/france/bourgogne/dijon/2020/08/21/
# 86 20 True 0
# 86 16 False 0
# 2020 08 21 Reims 19:00:00
# https://www.historique-meteo.net/france/champagne-ardenne/reims/2020/08/21/
# 87 14 True 2
# 87 15 False 1
# Journée : 9, Buteur : B. Kamara, type : contre son camp, equipe : Reims
# B.Kamara
# Journée : 9, Buteur : W. Faes, type : but, equipe : Reims
# W.Faes
# Journée : 9, Buteur : L. Ajorque, type : but, equipe : Strasbourg
# L.Ajorque
# 2020 08 21 Monaco 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/monaco/2020/08/21/
# 88 3 True 4
# 88 12 False 0
# Journée : 9, Buteur : W. Ben Yedder, type : penalty, equipe : Monaco
# W.BenYedder
# Journée : 9, Buteur : G. Martins, type : but, equipe : Monaco
# G.Martins
# Journée : 9, Buteur : K. Volland, type : but, equipe : Monaco
# K.Volland
# Journée : 9, Buteur : K. Volland, type : but, equipe : Monaco
# K.Volland
# 2020 08 21 Lille 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lille/2020/08/21/
# 89 1 True 1
# 89 4 False 1
# Journée : 9, Buteur : J. Bamba, type : but, equipe : Lille
# J.Bamba
# Journée : 9, Buteur : M. Çelik, type : but, equipe : Lyon
# M.Çelik
# 2020 08 21 Marseille 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/marseille/2020/08/21/
# 90 5 True 0
# 90 7 False 1
# Journée : 9, Buteur : S. Banza, type : but, equipe : Lens
# S.Banza
# 2020 08 21 Strasbourg 19:00:00
# https://www.historique-meteo.net/france/alsace/strasbourg/2020/08/21/
# 91 15 True 0
# 91 5 False 1
# Journée : 10, Buteur : M. Sanson, type : but, equipe : Marseille
# M.Sanson
# 2020 08 21 Bordeaux 19:00:00
# https://www.historique-meteo.net/france/aquitaine/bordeaux/2020/08/21/
# 92 12 True 0
# 92 8 False 2
# Journée : 10, Buteur : F. Mollet, type : but, equipe : Montpellier
# F.Mollet
# Journée : 10, Buteur : A. Delort, type : but, equipe : Montpellier
# A.Delort
# 2020 08 21 Paris 19:00:00
# https://www.historique-meteo.net/france/ile-de-france/paris/2020/08/21/
# 93 2 True 3
# 93 6 False 0
# Journée : 10, Buteur : M. Kean, type : but, equipe : Paris-SG
# M.Kean
# Journée : 10, Buteur : A. Di Maria, type : but, equipe : Paris-SG
# A.DiMaria
# Journée : 10, Buteur : D. Da Silva, type : contre son camp, equipe : Paris-SG
# D.DaSilva
# 2020 08 21 Brest 19:00:00
# https://www.historique-meteo.net/france/bretagne/brest/2020/08/21/
# 94 17 True 3
# 94 1 False 2
# Journée : 10, Buteur : R. Pierre-Gabriel, type : but, equipe : Brest
# R.Pierre-Gabriel
# Journée : 10, Buteur : R. Perraud, type : but, equipe : Brest
# R.Perraud
# Journée : 10, Buteur : I. Cardona, type : but, equipe : Brest
# I.Cardona
# Journée : 10, Buteur : B. Yilmaz, type : but, equipe : Lille
# B.Yilmaz
# Journée : 10, Buteur : B. Yilmaz, type : but, equipe : Lille
# B.Yilmaz
# 2020 08 21 Lens 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lens/2020/08/21/
# 95 7 True 4
# 95 14 False 4
# Journée : 10, Buteur : S. Banza, type : but, equipe : Lens
# S.Banza
# Journée : 10, Buteur : T. Foket, type : contre son camp, equipe : Lens
# T.Foket
# Journée : 10, Buteur : F. Sotoca, type : but, equipe : Lens
# F.Sotoca
# Journée : 10, Buteur : F. Sotoca, type : but, equipe : Lens
# F.Sotoca
# Journée : 10, Buteur : M. Cafaro, type : but, equipe : Reims
# M.Cafaro
# Journée : 10, Buteur : B. Dia, type : but, equipe : Reims
# B.Dia
# Journée : 10, Buteur : F. Medina, type : but, equipe : Reims
# F.Medina
# Journée : 10, Buteur : B. Dia, type : but, equipe : Reims
# B.Dia
# 2020 08 21 Metz 19:00:00
# https://www.historique-meteo.net/france/lorraine/metz/2020/08/21/
# 96 10 True 1
# 96 20 False 1
# Journée : 10, Buteur : P. Yade, type : but, equipe : Metz
# P.Yade
# Journée : 10, Buteur : M. Baldé, type : but, equipe : Dijon
# M.Baldé
# 2020 08 21 Nîmes 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/nimes/2020/08/21/
# 97 19 True 1
# 97 13 False 5
# Journée : 10, Buteur : M. Koné, type : but, equipe : Nîmes
# M.Koné
# Journée : 10, Buteur : M. Pereira Lage, type : but, equipe : Angers
# M.PereiraLage
# Journée : 10, Buteur : S. Bahoken, type : but, equipe : Angers
# S.Bahoken
# Journée : 10, Buteur : S. Bahoken, type : but, equipe : Angers
# S.Bahoken
# Journée : 10, Buteur : L. Diony, type : but, equipe : Angers
# L.Diony
# Journée : 10, Buteur : J. Cabot, type : but, equipe : Angers
# J.Cabot
# 2020 08 21 Lorient 19:00:00
# https://www.historique-meteo.net/france/bretagne/lorient/2020/08/21/
# 98 16 True 0
# 98 18 False 2
# Journée : 10, Buteur : A. Bamba, type : but, equipe : Nantes
# A.Bamba
# Journée : 10, Buteur : L. Blas, type : but, equipe : Nantes
# L.Blas
# 2020 08 21 Nice 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/nice/2020/08/21/
# 99 9 True 1
# 99 3 False 2
# Journée : 10, Buteur : P. Lees-Melou, type : but, equipe : Nice
# P.Lees-Melou
# Journée : 10, Buteur : A. Disasi, type : but, equipe : Monaco
# A.Disasi
# Journée : 10, Buteur : S. Diop, type : but, equipe : Monaco
# S.Diop
# 2020 08 21 Lyon 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/lyon/2020/08/21/
# 100 4 True 2
# 100 11 False 1
# Journée : 10, Buteur : T. Kadewere, type : but, equipe : Lyon
# T.Kadewere
# Journée : 10, Buteur : T. Kadewere, type : but, equipe : Lyon
# T.Kadewere
# Journée : 10, Buteur : A. Lopes, type : but, equipe : Saint-Étienne
# A.Lopes
# 2020 08 21 Rennes 19:00:00
# https://www.historique-meteo.net/france/bretagne/rennes/2020/08/21/
# 101 6 True 0
# 101 12 False 1
# Journée : 11, Buteur : H. Ben Arfa, type : but, equipe : Bordeaux
# H.BenArfa
# 2020 08 21 Monaco 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/monaco/2020/08/21/
# 102 3 True 3
# 102 2 False 2
# Journée : 11, Buteur : K. Volland, type : but, equipe : Monaco
# K.Volland
# Journée : 11, Buteur : K. Volland, type : but, equipe : Monaco
# K.Volland
# Journée : 11, Buteur : F. Fabregas, type : penalty, equipe : Monaco
# F.Fabregas
# Journée : 11, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# Journée : 11, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# 2020 08 21 Brest 19:00:00
# https://www.historique-meteo.net/france/bretagne/brest/2020/08/21/
# 103 17 True 4
# 103 11 False 1
# Journée : 11, Buteur : F. Honorat, type : but, equipe : Brest
# F.Honorat
# Journée : 11, Buteur : J. Duverne, type : but, equipe : Brest
# J.Duverne
# Journée : 11, Buteur : I. Cardona, type : but, equipe : Brest
# I.Cardona
# Journée : 11, Buteur : S. Mounié, type : but, equipe : Brest
# S.Mounié
# Journée : 11, Buteur : M. Camara, type : but, equipe : Saint-Étienne
# M.Camara
# 2020 08 21 Nantes 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/nantes/2020/08/21/
# 104 18 True 1
# 104 10 False 1
# Journée : 11, Buteur : R. Kolo Muani, type : but, equipe : Nantes
# R.KoloMuani
# Journée : 11, Buteur : A. Leya Iseka, type : but, equipe : Metz
# A.LeyaIseka
# 2020 08 21 Montpellier 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/montpellier/2020/08/21/
# 105 8 True 4
# 105 15 False 3
# Journée : 11, Buteur : P. Mendes, type : but, equipe : Montpellier
# P.Mendes
# Journée : 11, Buteur : A. Delort, type : but, equipe : Montpellier
# A.Delort
# Journée : 11, Buteur : A. Delort, type : but, equipe : Montpellier
# A.Delort
# Journée : 11, Buteur : G. Laborde, type : but, equipe : Montpellier
# G.Laborde
# Journée : 11, Buteur : K. Lala, type : but, equipe : Strasbourg
# K.Lala
# Journée : 11, Buteur : H. Diallo, type : but, equipe : Strasbourg
# H.Diallo
# Journée : 11, Buteur : L. Ajorque, type : but, equipe : Strasbourg
# L.Ajorque
# 2020 08 21 Dijon 19:00:00
# https://www.historique-meteo.net/france/bourgogne/dijon/2020/08/21/
# 106 20 True 0
# 106 7 False 1
# Journée : 11, Buteur : A. Kalimuendo, type : but, equipe : Lens
# A.Kalimuendo
# 2020 08 21 Reims 19:00:00
# https://www.historique-meteo.net/france/champagne-ardenne/reims/2020/08/21/
# 107 14 True 0
# 107 19 False 1
# Journée : 11, Buteur : R. Ripart, type : but, equipe : Nîmes
# R.Ripart
# 2020 08 21 Angers 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/angers/2020/08/21/
# 108 13 True 0
# 108 4 False 1
# Journée : 11, Buteur : T. Kadewere, type : but, equipe : Lyon
# T.Kadewere
# 2020 08 21 Lille 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lille/2020/08/21/
# 109 1 True 4
# 109 16 False 0
# Journée : 11, Buteur : Y. Yazici, type : but, equipe : Lille
# Y.Yazici
# Journée : 11, Buteur : Y. Yazici, type : but, equipe : Lille
# Y.Yazici
# Journée : 11, Buteur : L. Araujo, type : but, equipe : Lille
# L.Araujo
# Journée : 11, Buteur : J. David, type : but, equipe : Lille
# J.David
# 2020 08 21 Marseille 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/marseille/2020/08/21/
# 110 5 True 3
# 110 9 False 2
# Journée : 11, Buteur : A. Gonzalez, type : but, equipe : Marseille
# A.Gonzalez
# Journée : 11, Buteur : S. Khaoui, type : but, equipe : Marseille
# S.Khaoui
# Journée : 11, Buteur : S. Khaoui, type : but, equipe : Marseille
# S.Khaoui
# Journée : 11, Buteur : A. Gouiri, type : but, equipe : Nice
# A.Gouiri
# Journée : 11, Buteur : M. Sellouki, type : but, equipe : Nice
# M.Sellouki
# 2020 08 21 Strasbourg 19:00:00
# https://www.historique-meteo.net/france/alsace/strasbourg/2020/08/21/
# 111 15 True 1
# 111 6 False 1
# Journée : 12, Buteur : A. Thomasson, type : but, equipe : Strasbourg
# A.Thomasson
# Journée : 12, Buteur : A. Hunou, type : but, equipe : Rennes
# A.Hunou
# 2020 08 21 Marseille 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/marseille/2020/08/21/
# 112 5 True 3
# 112 18 False 1
# Journée : 12, Buteur : F. Thauvin, type : but, equipe : Marseille
# F.Thauvin
# Journée : 12, Buteur : D. Payet, type : but, equipe : Marseille
# D.Payet
# Journée : 12, Buteur : D. Benedetto, type : penalty, equipe : Marseille
# D.Benedetto
# Journée : 12, Buteur : L. Blas, type : but, equipe : Nantes
# L.Blas
# 2020 08 21 Paris 19:00:00
# https://www.historique-meteo.net/france/ile-de-france/paris/2020/08/21/
# 113 2 True 2
# 113 12 False 2
# Journée : 12, Buteur : Neymar, type : penalty, equipe : Paris-SG
# Neymar
# Journée : 12, Buteur : M. Kean, type : but, equipe : Paris-SG
# M.Kean
# Journée : 12, Buteur : T. Pembélé, type : but, equipe : Bordeaux
# T.Pembélé
# Journée : 12, Buteur : Y. Adli, type : but, equipe : Bordeaux
# Y.Adli
# 2020 08 21 Lyon 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/lyon/2020/08/21/
# 114 4 True 3
# 114 14 False 0
# Journée : 12, Buteur : K. Toko Ekambi, type : but, equipe : Lyon
# K.TokoEkambi
# Journée : 12, Buteur : B. Guimaraes, type : but, equipe : Lyon
# B.Guimaraes
# Journée : 12, Buteur : M. Dembélé, type : but, equipe : Lyon
# M.Dembélé
# 2020 08 21 Lens 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lens/2020/08/21/
# 115 7 True 1
# 115 13 False 3
# Journée : 12, Buteur : A. Kalimuendo, type : but, equipe : Lens
# A.Kalimuendo
# Journée : 12, Buteur : M. Pereira Lage, type : but, equipe : Angers
# M.PereiraLage
# Journée : 12, Buteur : S. Bahoken, type : but, equipe : Angers
# S.Bahoken
# Journée : 12, Buteur : P. Capelle, type : but, equipe : Angers
# P.Capelle
# 2020 08 21 Lorient 19:00:00
# https://www.historique-meteo.net/france/bretagne/lorient/2020/08/21/
# 116 16 True 0
# 116 8 False 1
# Journée : 12, Buteur : P. Skuletic, type : but, equipe : Montpellier
# P.Skuletic
# 2020 08 21 Monaco 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/monaco/2020/08/21/
# 117 3 True 3
# 117 19 False 0
# Journée : 12, Buteur : S. Diop, type : but, equipe : Monaco
# S.Diop
# Journée : 12, Buteur : G. Martins, type : but, equipe : Monaco
# G.Martins
# Journée : 12, Buteur : K. Volland, type : but, equipe : Monaco
# K.Volland
# 2020 08 21 Metz 19:00:00
# https://www.historique-meteo.net/france/lorraine/metz/2020/08/21/
# 118 10 True 0
# 118 17 False 2
# Journée : 12, Buteur : I. Cardona, type : but, equipe : Brest
# I.Cardona
# Journée : 12, Buteur : I. Cardona, type : but, equipe : Brest
# I.Cardona
# 2020 08 21 Nice 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/nice/2020/08/21/
# 119 9 True 1
# 119 20 False 3
# Journée : 12, Buteur : A. Gouiri, type : penalty, equipe : Nice
# A.Gouiri
# Journée : 12, Buteur : M. Baldé, type : but, equipe : Dijon
# M.Baldé
# Journée : 12, Buteur : G. Ngonda Muzinga, type : but, equipe : Dijon
# G.NgondaMuzinga
# Journée : 12, Buteur : M. Baldé, type : but, equipe : Dijon
# M.Baldé
# 2020 08 21 Saint-Étienne 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/saint-etienne/2020/08/21/
# 120 11 True 1
# 120 1 False 1
# Journée : 12, Buteur : W. Khazri, type : penalty, equipe : Saint-Étienne
# W.Khazri
# Journée : 12, Buteur : J. Ikoné, type : but, equipe : Lille
# J.Ikoné
# 2020 08 21 Nîmes 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/nimes/2020/08/21/
# 121 19 True 0
# 121 5 False 2
# Journée : 13, Buteur : D. Benedetto, type : but, equipe : Marseille
# D.Benedetto
# Journée : 13, Buteur : V. Germain, type : but, equipe : Marseille
# V.Germain
# 2020 08 21 Rennes 19:00:00
# https://www.historique-meteo.net/france/bretagne/rennes/2020/08/21/
# 122 6 True 0
# 122 7 False 2
# Journée : 13, Buteur : A. Kalimuendo, type : but, equipe : Lens
# A.Kalimuendo
# Journée : 13, Buteur : I. Ganago, type : but, equipe : Lens
# I.Ganago
# 2020 08 21 Montpellier 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/montpellier/2020/08/21/
# 123 8 True 1
# 123 2 False 3
# Journée : 13, Buteur : S. Mavididi, type : but, equipe : Montpellier
# S.Mavididi
# Journée : 13, Buteur : C. Dagba, type : but, equipe : Paris-SG
# C.Dagba
# Journée : 13, Buteur : M. Kean, type : but, equipe : Paris-SG
# M.Kean
# Journée : 13, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# 2020 08 21 Lille 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lille/2020/08/21/
# 124 1 True 2
# 124 3 False 1
# Journée : 13, Buteur : J. David, type : but, equipe : Lille
# J.David
# Journée : 13, Buteur : Y. Yazici, type : but, equipe : Lille
# Y.Yazici
# Journée : 13, Buteur : P. Pellegri, type : but, equipe : Monaco
# P.Pellegri
# 2020 08 21 Angers 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/angers/2020/08/21/
# 125 13 True 2
# 125 16 False 0
# Journée : 13, Buteur : A. Fulgini, type : but, equipe : Angers
# A.Fulgini
# Journée : 13, Buteur : P. Capelle, type : but, equipe : Angers
# P.Capelle
# 2020 08 21 Bordeaux 19:00:00
# https://www.historique-meteo.net/france/aquitaine/bordeaux/2020/08/21/
# 126 12 True 1
# 126 17 False 0
# Journée : 13, Buteur : H. Ben Arfa, type : but, equipe : Bordeaux
# H.BenArfa
# 2020 08 21 Nantes 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/nantes/2020/08/21/
# 127 18 True 0
# 127 15 False 4
# Journée : 13, Buteur : D. Liénard, type : but, equipe : Strasbourg
# D.Liénard
# Journée : 13, Buteur : H. Diallo, type : but, equipe : Strasbourg
# H.Diallo
# Journée : 13, Buteur : L. Ajorque, type : but, equipe : Strasbourg
# L.Ajorque
# Journée : 13, Buteur : K. Zohi, type : but, equipe : Strasbourg
# K.Zohi
# 2020 08 21 Dijon 19:00:00
# https://www.historique-meteo.net/france/bourgogne/dijon/2020/08/21/
# 128 20 True 0
# 128 11 False 0
# 2020 08 21 Reims 19:00:00
# https://www.historique-meteo.net/france/champagne-ardenne/reims/2020/08/21/
# 129 14 True 0
# 129 9 False 0
# 2020 08 21 Metz 19:00:00
# https://www.historique-meteo.net/france/lorraine/metz/2020/08/21/
# 130 10 True 1
# 130 4 False 3
# Journée : 13, Buteur : F. Boulaya, type : but, equipe : Metz
# F.Boulaya
# Journée : 13, Buteur : M. Depay, type : but, equipe : Lyon
# M.Depay
# Journée : 13, Buteur : K. Toko Ekambi, type : but, equipe : Lyon
# K.TokoEkambi
# Journée : 13, Buteur : K. Toko Ekambi, type : but, equipe : Lyon
# K.TokoEkambi
# 2020 08 21 Saint-Étienne 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/saint-etienne/2020/08/21/
# 131 11 True 0
# 131 13 False 0
# 2020 08 21 Marseille 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/marseille/2020/08/21/
# 132 5 True 2
# 132 3 False 1
# Journée : 14, Buteur : F. Thauvin, type : but, equipe : Marseille
# F.Thauvin
# Journée : 14, Buteur : D. Benedetto, type : but, equipe : Marseille
# D.Benedetto
# Journée : 14, Buteur : W. Ben Yedder, type : but, equipe : Monaco
# W.BenYedder
# 2020 08 21 Lens 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lens/2020/08/21/
# 133 7 True 2
# 133 8 False 3
# Journée : 14, Buteur : J. Omlin, type : contre son camp, equipe : Lens
# J.Omlin
# Journée : 14, Buteur : G. Kakuta, type : penalty, equipe : Lens
# G.Kakuta
# Journée : 14, Buteur : S. Mavididi, type : but, equipe : Montpellier
# S.Mavididi
# Journée : 14, Buteur : P. Mendes, type : but, equipe : Montpellier
# P.Mendes
# Journée : 14, Buteur : G. Laborde, type : but, equipe : Montpellier
# G.Laborde
# 2020 08 21 Nice 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/nice/2020/08/21/
# 134 9 True 0
# 134 6 False 1
# Journée : 14, Buteur : M. Niang, type : but, equipe : Rennes
# M.Niang
# 2020 08 21 Brest 19:00:00
# https://www.historique-meteo.net/france/bretagne/brest/2020/08/21/
# 135 17 True 2
# 135 14 False 1
# Journée : 14, Buteur : F. Honorat, type : but, equipe : Brest
# F.Honorat
# Journée : 14, Buteur : S. Mounié, type : but, equipe : Brest
# S.Mounié
# Journée : 14, Buteur : A. Zeneli, type : but, equipe : Reims
# A.Zeneli
# 2020 08 21 Strasbourg 19:00:00
# https://www.historique-meteo.net/france/alsace/strasbourg/2020/08/21/
# 136 15 True 2
# 136 10 False 2
# Journée : 14, Buteur : M. Simakan, type : but, equipe : Strasbourg
# M.Simakan
# Journée : 14, Buteur : A. Thomasson, type : but, equipe : Strasbourg
# A.Thomasson
# Journée : 14, Buteur : D. Bronn, type : but, equipe : Metz
# D.Bronn
# Journée : 14, Buteur : O. Nguette, type : but, equipe : Metz
# O.Nguette
# 2020 08 21 Nantes 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/nantes/2020/08/21/
# 137 18 True 1
# 137 20 False 1
# Journée : 14, Buteur : M. Simon, type : penalty, equipe : Nantes
# M.Simon
# Journée : 14, Buteur : M. Konaté, type : but, equipe : Dijon
# M.Konaté
# 2020 08 21 Lorient 19:00:00
# https://www.historique-meteo.net/france/bretagne/lorient/2020/08/21/
# 138 16 True 3
# 138 19 False 0
# Journée : 14, Buteur : Q. Boisgard, type : but, equipe : Lorient
# Q.Boisgard
# Journée : 14, Buteur : P. Hamel, type : penalty, equipe : Lorient
# P.Hamel
# Journée : 14, Buteur : Y. Wissa, type : but, equipe : Lorient
# Y.Wissa
# 2020 08 21 Lille 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lille/2020/08/21/
# 139 1 True 2
# 139 12 False 1
# Journée : 14, Buteur : J. Bamba, type : but, equipe : Lille
# J.Bamba
# Journée : 14, Buteur : J. Fonte, type : but, equipe : Lille
# J.Fonte
# Journée : 14, Buteur : T. Basic, type : but, equipe : Bordeaux
# T.Basic
# 2020 08 21 Paris 19:00:00
# https://www.historique-meteo.net/france/ile-de-france/paris/2020/08/21/
# 140 2 True 0
# 140 4 False 1
# Journée : 14, Buteur : T. Kadewere, type : but, equipe : Lyon
# T.Kadewere
# 2020 08 21 Dijon 19:00:00
# https://www.historique-meteo.net/france/bourgogne/dijon/2020/08/21/
# 141 20 True 0
# 141 1 False 2
# Journée : 15, Buteur : Y. Yazici, type : but, equipe : Lille
# Y.Yazici
# Journée : 15, Buteur : T. Weah, type : but, equipe : Lille
# T.Weah
# 2020 08 21 Montpellier 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/montpellier/2020/08/21/
# 142 8 True 0
# 142 10 False 2
# Journée : 15, Buteur : A. Leya Iseka, type : but, equipe : Metz
# A.LeyaIseka
# Journée : 15, Buteur : H. Maïga, type : but, equipe : Metz
# H.Maïga
# 2020 08 21 Angers 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/angers/2020/08/21/
# 143 13 True 0
# 143 15 False 2
# Journée : 15, Buteur : H. Diallo, type : but, equipe : Strasbourg
# H.Diallo
# Journée : 15, Buteur : L. Ajorque, type : but, equipe : Strasbourg
# L.Ajorque
# 2020 08 21 Nîmes 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/nimes/2020/08/21/
# 144 19 True 0
# 144 9 False 2
# Journée : 15, Buteur : D. Ndoye, type : but, equipe : Nice
# D.Ndoye
# Journée : 15, Buteur : A. Claude-Maurice, type : but, equipe : Nice
# A.Claude-Maurice
# 2020 08 21 Reims 19:00:00
# https://www.historique-meteo.net/france/champagne-ardenne/reims/2020/08/21/
# 145 14 True 3
# 145 18 False 2
# Journée : 15, Buteur : E. Touré, type : but, equipe : Reims
# E.Touré
# Journée : 15, Buteur : B. Dia, type : penalty, equipe : Reims
# B.Dia
# Journée : 15, Buteur : M. Cafaro, type : but, equipe : Reims
# M.Cafaro
# ...
# https://www.historique-meteo.net/france/bretagne/rennes/2020/08/21/
# 336 6 True 5
# 336 20 False 1
# Journée : 34, Buteur : M. Terrier, type : but, equipe : Rennes
# M.Terrier
# Journée : 34, Buteur : M. Terrier, type : but, equipe : Rennes
# M.Terrier
# Journée : 34, Buteur : F. Tait, type : but, equipe : Rennes
# F.Tait
# Journée : 34, Buteur : G. Nyamsi, type : but, equipe : Rennes
# G.Nyamsi
# Journée : 34, Buteur : C. Grenier, type : but, equipe : Rennes
# C.Grenier
# Journée : 34, Buteur : Y. Benzia, type : but, equipe : Dijon
# Y.Benzia
# 2020 08 21 Strasbourg 19:00:00
# https://www.historique-meteo.net/france/alsace/strasbourg/2020/08/21/
# 337 15 True 1
# 337 18 False 2
# Journée : 34, Buteur : L. Ajorque, type : but, equipe : Strasbourg
# L.Ajorque
# Journée : 34, Buteur : J. Castelletto, type : but, equipe : Nantes
# J.Castelletto
# Journée : 34, Buteur : L. Blas, type : but, equipe : Nantes
# L.Blas
# 2020 08 21 Lorient 19:00:00
# https://www.historique-meteo.net/france/bretagne/lorient/2020/08/21/
# 338 16 True 4
# 338 12 False 1
# Journée : 34, Buteur : Y. Wissa, type : but, equipe : Lorient
# Y.Wissa
# Journée : 34, Buteur : T. Moffi, type : but, equipe : Lorient
# T.Moffi
# Journée : 34, Buteur : T. Moffi, type : but, equipe : Lorient
# T.Moffi
# Journée : 34, Buteur : T. Moffi, type : but, equipe : Lorient
# T.Moffi
# Journée : 34, Buteur : I. Sissokho, type : but, equipe : Bordeaux
# I.Sissokho
# 2020 08 21 Angers 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/angers/2020/08/21/
# 339 13 True 0
# 339 3 False 1
# Journée : 34, Buteur : W. Ben Yedder, type : but, equipe : Monaco
# W.BenYedder
# 2020 08 21 Lyon 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/lyon/2020/08/21/
# 340 4 True 2
# 340 1 False 3
# Journée : 34, Buteur : I. Slimani, type : but, equipe : Lyon
# I.Slimani
# Journée : 34, Buteur : J. Fonte, type : contre son camp, equipe : Lyon
# J.Fonte
# Journée : 34, Buteur : B. Yilmaz, type : but, equipe : Lille
# B.Yilmaz
# Journée : 34, Buteur : J. David, type : but, equipe : Lille
# J.David
# Journée : 34, Buteur : B. Yilmaz, type : but, equipe : Lille
# B.Yilmaz
# 2020 08 21 Marseille 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/marseille/2020/08/21/
# 341 5 True 1
# 341 15 False 1
# Journée : 35, Buteur : D. Benedetto, type : but, equipe : Marseille
# D.Benedetto
# Journée : 35, Buteur : S. Mitrovic, type : but, equipe : Strasbourg
# S.Mitrovic
# 2020 08 21 Paris 19:00:00
# https://www.historique-meteo.net/france/ile-de-france/paris/2020/08/21/
# 342 2 True 2
# 342 7 False 1
# Journée : 35, Buteur : Neymar, type : but, equipe : Paris-SG
# Neymar
# Journée : 35, Buteur : Marquinhos, type : but, equipe : Paris-SG
# Marquinhos
# Journée : 35, Buteur : I. Ganago, type : but, equipe : Lens
# I.Ganago
# 2020 08 21 Lille 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lille/2020/08/21/
# 343 1 True 2
# 343 9 False 0
# Journée : 35, Buteur : B. Yilmaz, type : but, equipe : Lille
# B.Yilmaz
# Journée : 35, Buteur : M. Çelik, type : but, equipe : Lille
# M.Çelik
# 2020 08 21 Bordeaux 19:00:00
# https://www.historique-meteo.net/france/aquitaine/bordeaux/2020/08/21/
# 344 12 True 1
# 344 6 False 0
# Journée : 35, Buteur : S. Mara, type : but, equipe : Bordeaux
# S.Mara
# 2020 08 21 Dijon 19:00:00
# https://www.historique-meteo.net/france/bourgogne/dijon/2020/08/21/
# 345 20 True 1
# 345 10 False 5
# Journée : 35, Buteur : M. Baldé, type : but, equipe : Dijon
# M.Baldé
# Journée : 35, Buteur : M. Gueye, type : but, equipe : Metz
# M.Gueye
# Journée : 35, Buteur : P. Sarr, type : but, equipe : Metz
# P.Sarr
# Journée : 35, Buteur : F. Chafik, type : but, equipe : Metz
# F.Chafik
# Journée : 35, Buteur : V. Dias Goncalves, type : but, equipe : Metz
# V.DiasGoncalves
# Journée : 35, Buteur : D. Bronn, type : but, equipe : Metz
# D.Bronn
# 2020 08 21 Nîmes 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/nimes/2020/08/21/
# 346 19 True 2
# 346 14 False 2
# Journée : 35, Buteur : R. Ripart, type : but, equipe : Nîmes
# R.Ripart
# Journée : 35, Buteur : M. Koné, type : but, equipe : Nîmes
# M.Koné
# Journée : 35, Buteur : N. Mbuku, type : but, equipe : Reims
# N.Mbuku
# Journée : 35, Buteur : A. Flips, type : but, equipe : Reims
# A.Flips
# 2020 08 21 Lorient 19:00:00
# https://www.historique-meteo.net/france/bretagne/lorient/2020/08/21/
# 347 16 True 2
# 347 13 False 0
# Journée : 35, Buteur : Y. Wissa, type : penalty, equipe : Lorient
# Y.Wissa
# Journée : 35, Buteur : F. Lemoine, type : but, equipe : Lorient
# F.Lemoine
# 2020 08 21 Brest 19:00:00
# https://www.historique-meteo.net/france/bretagne/brest/2020/08/21/
# 348 17 True 1
# 348 18 False 4
# Journée : 35, Buteur : R. Faivre, type : but, equipe : Brest
# R.Faivre
# Journée : 35, Buteur : M. Simon, type : but, equipe : Nantes
# M.Simon
# Journée : 35, Buteur : L. Blas, type : but, equipe : Nantes
# L.Blas
# Journée : 35, Buteur : I. Louza, type : but, equipe : Nantes
# I.Louza
# Journée : 35, Buteur : K. Coulibaly, type : but, equipe : Nantes
# K.Coulibaly
# 2020 08 21 Montpellier 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/montpellier/2020/08/21/
# 349 8 True 1
# 349 11 False 2
# Journée : 35, Buteur : A. Delort, type : but, equipe : Montpellier
# A.Delort
# Journée : 35, Buteur : R. Hamouma, type : but, equipe : Saint-Étienne
# R.Hamouma
# Journée : 35, Buteur : M. Debuchy, type : but, equipe : Saint-Étienne
# M.Debuchy
# 2020 08 21 Monaco 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/monaco/2020/08/21/
# 350 3 True 2
# 350 4 False 3
# Journée : 35, Buteur : K. Volland, type : but, equipe : Monaco
# K.Volland
# Journée : 35, Buteur : W. Ben Yedder, type : penalty, equipe : Monaco
# W.BenYedder
# Journée : 35, Buteur : M. Depay, type : but, equipe : Lyon
# M.Depay
# Journée : 35, Buteur : Marcelo, type : but, equipe : Lyon
# Marcelo
# Journée : 35, Buteur : R. Cherki, type : but, equipe : Lyon
# R.Cherki
# 2020 08 21 Lens 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lens/2020/08/21/
# 351 7 True 0
# 351 1 False 3
# Journée : 36, Buteur : B. Yilmaz, type : but, equipe : Lille
# B.Yilmaz
# Journée : 36, Buteur : B. Yilmaz, type : but, equipe : Lille
# B.Yilmaz
# Journée : 36, Buteur : J. David, type : but, equipe : Lille
# J.David
# 2020 08 21 Nantes 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/nantes/2020/08/21/
# 352 18 True 3
# 352 12 False 0
# Journée : 36, Buteur : K. Coulibaly, type : but, equipe : Nantes
# K.Coulibaly
# Journée : 36, Buteur : I. Louza, type : penalty, equipe : Nantes
# I.Louza
# Journée : 36, Buteur : R. Kolo Muani, type : but, equipe : Nantes
# R.KoloMuani
# 2020 08 21 Lyon 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/lyon/2020/08/21/
# 353 4 True 4
# 353 16 False 1
# Journée : 36, Buteur : H. Aouar, type : but, equipe : Lyon
# H.Aouar
# Journée : 36, Buteur : L. Paqueta, type : but, equipe : Lyon
# L.Paqueta
# Journée : 36, Buteur : B. Guimaraes, type : penalty, equipe : Lyon
# B.Guimaraes
# Journée : 36, Buteur : B. Guimaraes, type : but, equipe : Lyon
# B.Guimaraes
# Journée : 36, Buteur : T. Monconduit, type : but, equipe : Lorient
# T.Monconduit
# 2020 08 21 Saint-Étienne 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/saint-etienne/2020/08/21/
# 354 11 True 1
# 354 5 False 0
# Journée : 36, Buteur : A. Nordin, type : but, equipe : Saint-Étienne
# A.Nordin
# 2020 08 21 Strasbourg 19:00:00
# https://www.historique-meteo.net/france/alsace/strasbourg/2020/08/21/
# 355 15 True 2
# 355 8 False 3
# Journée : 36, Buteur : L. Ajorque, type : but, equipe : Strasbourg
# L.Ajorque
# Journée : 36, Buteur : K. Zohi, type : but, equipe : Strasbourg
# K.Zohi
# Journée : 36, Buteur : G. Laborde, type : but, equipe : Montpellier
# G.Laborde
# Journée : 36, Buteur : A. Delort, type : but, equipe : Montpellier
# A.Delort
# Journée : 36, Buteur : G. Laborde, type : but, equipe : Montpellier
# G.Laborde
# 2020 08 21 Metz 19:00:00
# https://www.historique-meteo.net/france/lorraine/metz/2020/08/21/
# 356 10 True 0
# 356 19 False 3
# Journée : 36, Buteur : L. Fomba, type : but, equipe : Nîmes
# L.Fomba
# Journée : 36, Buteur : R. Ripart, type : but, equipe : Nîmes
# R.Ripart
# Journée : 36, Buteur : Z. Ferhat, type : but, equipe : Nîmes
# Z.Ferhat
# 2020 08 21 Nice 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/nice/2020/08/21/
# 357 9 True 3
# 357 17 False 2
# Journée : 36, Buteur : R. Lopes, type : but, equipe : Nice
# R.Lopes
# Journée : 36, Buteur : H. Boudaoui, type : but, equipe : Nice
# H.Boudaoui
# Journée : 36, Buteur : H. Kamara, type : but, equipe : Nice
# H.Kamara
# Journée : 36, Buteur : S. Mounié, type : but, equipe : Brest
# S.Mounié
# Journée : 36, Buteur : S. Mounié, type : but, equipe : Brest
# S.Mounié
# 2020 08 21 Angers 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/angers/2020/08/21/
# 358 13 True 3
# 358 20 False 0
# Journée : 36, Buteur : A. Fulgini, type : but, equipe : Angers
# A.Fulgini
# Journée : 36, Buteur : F. El-Melali, type : but, equipe : Angers
# F.El-Melali
# Journée : 36, Buteur : L. Diony, type : but, equipe : Angers
# L.Diony
# 2020 08 21 Reims 19:00:00
# https://www.historique-meteo.net/france/champagne-ardenne/reims/2020/08/21/
# 359 14 True 0
# 359 3 False 1
# Journée : 36, Buteur : E. Matazo, type : but, equipe : Monaco
# E.Matazo
# 2020 08 21 Rennes 19:00:00
# https://www.historique-meteo.net/france/bretagne/rennes/2020/08/21/
# 360 6 True 1
# 360 2 False 1
# Journée : 36, Buteur : S. Guirassy, type : but, equipe : Rennes
# S.Guirassy
# Journée : 36, Buteur : Neymar, type : but, equipe : Paris-SG
# Neymar
# 2020 08 21 Lille 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lille/2020/08/21/
# 361 1 True 0
# 361 11 False 0
# 2020 08 21 Paris 19:00:00
# https://www.historique-meteo.net/france/ile-de-france/paris/2020/08/21/
# 362 2 True 4
# 362 14 False 0
# Journée : 37, Buteur : Neymar, type : penalty, equipe : Paris-SG
# Neymar
# Journée : 37, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# Journée : 37, Buteur : Marquinhos, type : but, equipe : Paris-SG
# Marquinhos
# Journée : 37, Buteur : M. Kean, type : but, equipe : Paris-SG
# M.Kean
# 2020 08 21 Monaco 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/monaco/2020/08/21/
# 363 3 True 2
# 363 6 False 1
# Journée : 37, Buteur : W. Ben Yedder, type : but, equipe : Monaco
# W.BenYedder
# Journée : 37, Buteur : A. Golovine, type : but, equipe : Monaco
# A.Golovine
# Journée : 37, Buteur : A. Disasi, type : but, equipe : Rennes
# A.Disasi
# 2020 08 21 Nîmes 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/nimes/2020/08/21/
# 364 19 True 2
# 364 4 False 5
# Journée : 37, Buteur : M. Koné, type : but, equipe : Nîmes
# M.Koné
# Journée : 37, Buteur : M. Koné, type : but, equipe : Nîmes
# M.Koné
# Journée : 37, Buteur : L. Paqueta, type : but, equipe : Lyon
# L.Paqueta
# Journée : 37, Buteur : M. Depay, type : but, equipe : Lyon
# M.Depay
# Journée : 37, Buteur : L. Paqueta, type : but, equipe : Lyon
# L.Paqueta
# Journée : 37, Buteur : H. Aouar, type : but, equipe : Lyon
# H.Aouar
# Journée : 37, Buteur : I. Slimani, type : but, equipe : Lyon
# I.Slimani
# 2020 08 21 Marseille 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/marseille/2020/08/21/
# 365 5 True 3
# 365 13 False 2
# Journée : 37, Buteur : A. Milik, type : but, equipe : Marseille
# A.Milik
# Journée : 37, Buteur : A. Milik, type : but, equipe : Marseille
# A.Milik
# Journée : 37, Buteur : A. Milik, type : penalty, equipe : Marseille
# A.Milik
# Journée : 37, Buteur : M. Pereira Lage, type : but, equipe : Angers
# M.PereiraLage
# Journée : 37, Buteur : R. Thomas, type : but, equipe : Angers
# R.Thomas
# 2020 08 21 Bordeaux 19:00:00
# https://www.historique-meteo.net/france/aquitaine/bordeaux/2020/08/21/
# 366 12 True 3
# 366 7 False 0
# Journée : 37, Buteur : U. Hwang, type : penalty, equipe : Bordeaux
# U.Hwang
# Journée : 37, Buteur : Y. Sabaly, type : but, equipe : Bordeaux
# Y.Sabaly
# Journée : 37, Buteur : M. Zerkane, type : but, equipe : Bordeaux
# M.Zerkane
# 2020 08 21 Montpellier 19:00:00
# https://www.historique-meteo.net/france/languedoc-roussillon/montpellier/2020/08/21/
# 367 8 True 0
# 367 17 False 0
# 2020 08 21 Nice 19:00:00
# https://www.historique-meteo.net/france/provence-alpes-c-te-d-azur/nice/2020/08/21/
# 368 9 True 0
# 368 15 False 2
# Journée : 37, Buteur : L. Ajorque, type : but, equipe : Strasbourg
# L.Ajorque
# Journée : 37, Buteur : L. Ajorque, type : but, equipe : Strasbourg
# L.Ajorque
# 2020 08 21 Lorient 19:00:00
# https://www.historique-meteo.net/france/bretagne/lorient/2020/08/21/
# 369 16 True 2
# 369 10 False 1
# Journée : 37, Buteur : Y. Wissa, type : penalty, equipe : Lorient
# Y.Wissa
# Journée : 37, Buteur : J. Hergault, type : but, equipe : Lorient
# J.Hergault
# Journée : 37, Buteur : B. Traoré, type : but, equipe : Metz
# B.Traoré
# 2020 08 21 Dijon 19:00:00
# https://www.historique-meteo.net/france/bourgogne/dijon/2020/08/21/
# 370 20 True 0
# 370 18 False 4
# Journée : 37, Buteur : K. Coulibaly, type : but, equipe : Nantes
# K.Coulibaly
# Journée : 37, Buteur : R. Kolo Muani, type : but, equipe : Nantes
# R.KoloMuani
# Journée : 37, Buteur : L. Blas, type : but, equipe : Nantes
# L.Blas
# Journée : 37, Buteur : R. Kolo Muani, type : but, equipe : Nantes
# R.KoloMuani
# 2020 08 21 Angers 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/angers/2020/08/21/
# 371 13 True 1
# 371 1 False 2
# Journée : 38, Buteur : A. Fulgini, type : but, equipe : Angers
# A.Fulgini
# Journée : 38, Buteur : J. David, type : but, equipe : Lille
# J.David
# Journée : 38, Buteur : B. Yilmaz, type : but, equipe : Lille
# B.Yilmaz
# 2020 08 21 Brest 19:00:00
# https://www.historique-meteo.net/france/bretagne/brest/2020/08/21/
# 372 17 True 0
# 372 2 False 2
# Journée : 38, Buteur : R. Faivre, type : but, equipe : Paris-SG
# R.Faivre
# Journée : 38, Buteur : K. Mbappé, type : but, equipe : Paris-SG
# K.Mbappé
# 2020 08 21 Lens 19:00:00
# https://www.historique-meteo.net/france/nord-pas-de-calais/lens/2020/08/21/
# 373 7 True 0
# 373 3 False 0
# 2020 08 21 Lyon 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/lyon/2020/08/21/
# 374 4 True 2
# 374 9 False 3
# Journée : 38, Buteur : K. Toko Ekambi, type : but, equipe : Lyon
# K.TokoEkambi
# Journée : 38, Buteur : K. Toko Ekambi, type : but, equipe : Lyon
# K.TokoEkambi
# Journée : 38, Buteur : K. Dolberg, type : but, equipe : Nice
# K.Dolberg
# Journée : 38, Buteur : H. Kamara, type : but, equipe : Nice
# H.Kamara
# Journée : 38, Buteur : W. Saliba, type : but, equipe : Nice
# W.Saliba
# 2020 08 21 Metz 19:00:00
# https://www.historique-meteo.net/france/lorraine/metz/2020/08/21/
# 375 10 True 1
# 375 5 False 1
# Journée : 38, Buteur : F. Boulaya, type : penalty, equipe : Metz
# F.Boulaya
# Journée : 38, Buteur : A. Milik, type : but, equipe : Marseille
# A.Milik
# 2020 08 21 Rennes 19:00:00
# https://www.historique-meteo.net/france/bretagne/rennes/2020/08/21/
# 376 6 True 2
# 376 19 False 0
# Journée : 38, Buteur : S. Guirassy, type : but, equipe : Rennes
# S.Guirassy
# Journée : 38, Buteur : B. Bourigeaud, type : but, equipe : Rennes
# B.Bourigeaud
# 2020 08 21 Nantes 19:00:00
# https://www.historique-meteo.net/france/pays-de-la-loire/nantes/2020/08/21/
# 377 18 True 1
# 377 8 False 2
# Journée : 38, Buteur : R. Kolo Muani, type : but, equipe : Nantes
# R.KoloMuani
# Journée : 38, Buteur : G. Laborde, type : but, equipe : Montpellier
# G.Laborde
# Journée : 38, Buteur : A. Delort, type : but, equipe : Montpellier
# A.Delort
# 2020 08 21 Saint-Étienne 19:00:00
# https://www.historique-meteo.net/france/rh-ne-alpes/saint-etienne/2020/08/21/
# 378 11 True 0
# 378 20 False 1
# Journée : 38, Buteur : A. Kamara, type : but, equipe : Dijon
# A.Kamara
# 2020 08 21 Reims 19:00:00
# https://www.historique-meteo.net/france/champagne-ardenne/reims/2020/08/21/
# 379 14 True 1
# 379 12 False 2
# Journée : 38, Buteur : E. Touré, type : but, equipe : Reims
# E.Touré
# Journée : 38, Buteur : Y. Adli, type : but, equipe : Bordeaux
# Y.Adli
# Journée : 38, Buteur : E. Kwateng, type : but, equipe : Bordeaux
# E.Kwateng
# 2020 08 21 Strasbourg 19:00:00
# https://www.historique-meteo.net/france/alsace/strasbourg/2020/08/21/
# 380 15 True 1
# 380 16 False 1
# Journée : 38, Buteur : H. Diallo, type : but, equipe : Strasbourg
# H.Diallo
# Journée : 38, Buteur : T. Chalobah, type : but, equipe : Lorient
# T.Chalobah

# %%
for i in range(len(df_match)):
    time.sleep(0.5)
    place = df_match.loc[i]['City']
    date = df_match.loc[i]['Date']
    hour = df_match.loc[i]['Hour']
    date = date.replace("-"," ")
    #print(date,place,hour)
    link_weather = functions.create_link_weather(place, date)
    #print(link_weather)
    tmax, rainfall = functions.scrapmeteo(link_weather)
    match_id = database.insert_table_matches(championship_id,date,place,rainfall,tmax)

    
    #matches_teams Dom
    name_city = df_home_team.loc[i]['Home']
    team_goal = df_home_team.loc[i]['HomeGoals']
    home=True

    team_id = database.get_team_id(name_city)
    #print(match_id, team_id, home, team_goal)
    database.insert_table_matches_teams(match_id, team_id, home, team_goal)
        
        
    #matches_teams Ext
    name_city = df_visitor_team.loc[i]['Visitor']
    team_goal = df_visitor_team.loc[i]['VisitorGoals']
    home=False

    team_id = database.get_team_id(name_city)
    #print(match_id, team_id, home, team_goal)
    database.insert_table_matches_teams(match_id, team_id, home, team_goal)
        
        

    #goals
    page = requests.get(df_scrap.loc[i]['Web'])
    soup = BeautifulSoup(page.text, 'html.parser')
    goalers = soup.find_all("span", {"class": "Scoreboard__scorer"})
    for j in range(len(goalers)):
        goal_type = soup.find_all("div", {"class": "Scoreboard__goals"})
        goal_type = goal_type[j].find_all('span')
        if ((goal_type[0].text or goal_type[2].text) != '(csc)' and (goal_type[0].text or goal_type[2].text) != '(s.p.)'):
            #print(f'Journée : {df_scrap.loc[i].Week}, Buteur : {goalers[j].text}, type : but')
            player_name = goalers[j].text.replace(" ","")
            #print(player_name)
            player_id = database.get_player_id(player_name)
            goal_type = "normal"
            database.insert_table_goals(player_id, match_id, goal_type)                
        elif ((goal_type[0].text or goal_type[2].text) == '(s.p.)'):
            #print(f'Journée : {df_scrap.loc[i].Week}, Buteur : {goalers[j].text}, type : penalty')
            player_name = goalers[j].text.replace(" ","")
            #print(player_name)
            player_id = database.get_player_id(player_name)
            goal_type = "penalty"
            database.insert_table_goals(player_id, match_id, goal_type)
        else:
            #print(f'Journée : {df_scrap.loc[i].Week}, Buteur : {goalers[j].text}, type : contre son camp')
            player_name = goalers[j].text.replace(" ","")
            #print(player_name)
            player_id = database.get_player_id(player_name)
            goal_type = "contre son camp"
            database.insert_table_goals(player_id, match_id, goal_type)
# Out:
# Journée : 1, Buteur : I. Traoré, type : but
# Journée : 1, Buteur : J. Bamba, type : but
# Journée : 1, Buteur : D. Da Silva, type : but
# Journée : 1, Buteur : A. Disasi, type : but
# Journée : 1, Buteur : B. Badiashile, type : but
# Journée : 1, Buteur : B. Dia, type : but
# Journée : 1, Buteur : E. Touré, type : but
# Journée : 1, Buteur : Y. Wissa, type : but
# Journée : 1, Buteur : A. Grbic, type : penalty
# Journée : 1, Buteur : P. Hamel, type : but
# Journée : 1, Buteur : M. Chahiri, type : but
# Journée : 1, Buteur : K. Denkey, type : but
# Journée : 1, Buteur : B. Meling, type : but
# Journée : 1, Buteur : R. Philippoteaux, type : but
# Journée : 1, Buteur : M. Koné, type : but
# Journée : 1, Buteur : A. Gouiri, type : but
# Journée : 1, Buteur : A. Gouiri, type : but
# Journée : 1, Buteur : G. Kakuta, type : but
# Journée : 1, Buteur : T. Savanier, type : penalty
# Journée : 1, Buteur : T. Savanier, type : but
# Journée : 1, Buteur : M. Depay, type : but
# Journée : 1, Buteur : J. Draxler, type : but
# Journée : 1, Buteur : R. Hamouma, type : but
# Journée : 1, Buteur : D. Bouanga, type : but
# Journée : 2, Buteur : M. Depay, type : penalty
# Journée : 2, Buteur : W. Lautoa, type : contre son camp
# Journée : 2, Buteur : M. Depay, type : but
# Journée : 2, Buteur : M. Depay, type : penalty
# Journée : 2, Buteur : A. Scheidler, type : but
# Journée : 2, Buteur : D. Le Tallec, type : contre son camp
# Journée : 2, Buteur : E. Camavinga, type : but
# Journée : 2, Buteur : G. Laborde, type : but
# Journée : 2, Buteur : K. Dolberg, type : but
# Journée : 2, Buteur : K. Dolberg, type : but
# Journée : 2, Buteur : J. Bamba, type : but
# Journée : 2, Buteur : A. Girotto, type : but
# Journée : 2, Buteur : I. Louza, type : penalty
# Journée : 2, Buteur : Z. Ferhat, type : but
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-36e770142c17> in <module>
#      34
#      35     #for i in range(len(df_scrap)):
# ---> 36     page = requests.get(df_scrap.loc[i]['Web'])
#      37     soup = BeautifulSoup(page.text, 'html.parser')
#      38     goalers = soup.find_all("span", {"class": "Scoreboard__scorer"})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     683
#     684         if not stream:
# --> 685             r.content
#     686
#     687         return r
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     569         """
#     570         if self.chunked and self.supports_chunked_reads():
# --> 571             for line in self.read_chunked(amt, decode_content=decode_content):
#     572                 yield line
#     573         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     761
#     762             while True:
# --> 763                 self._update_chunk_length()
#     764                 if self.chunk_left == 0:
#     765                     break
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/response.py in _update_chunk_length(self)
#     691         if self.chunk_left is not None:
#     692             return
# --> 693         line = self._fp.fp.readline()
#     694         line = line.split(b";", 1)[0]
#     695         try:
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
